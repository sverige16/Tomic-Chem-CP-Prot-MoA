# %%
import pandas as pd

# %%
paths_v1v2 = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/data_for_models/paths_to_channels_creation/paths_channels_treated_v1v2.csv')

# %%
paths_v1v2
# Out:
#        Unnamed: 0    plate well   compound  \
# 0               0  P015076  B04  CBK041257
# 1               1  P015076  B04  CBK041257
# 2               2  P015076  B04  CBK041257
# 3               3  P015076  B04  CBK041257
# 4               4  P015076  B04  CBK041257
# ...           ...      ...  ...        ...
# 91138       44005  P101031  O23  CBK011579
# 91139       44006  P101031  O23  CBK011579
# 91140       44007  P101031  O23  CBK011579
# 91141       44008  P101031  O23  CBK011579
# 91142       44009  P101031  O23  CBK011579
#
#                                                       C1  \
# 0      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 1      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 2      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 3      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 4      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# ...                                                  ...
# 91138  /share/data/external-datasets/compoundcenter/s...
# 91139  /share/data/external-datasets/compoundcenter/s...
# 91140  /share/data/external-datasets/compoundcenter/s...
# 91141  /share/data/external-datasets/compoundcenter/s...
# 91142  /share/data/external-datasets/compoundcenter/s...
#
#                                                       C2  \
# 0      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 1      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 2      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 3      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 4      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# ...                                                  ...
# 91138  /share/data/external-datasets/compoundcenter/s...
# 91139  /share/data/external-datasets/compoundcenter/s...
# 91140  /share/data/external-datasets/compoundcenter/s...
# 91141  /share/data/external-datasets/compoundcenter/s...
# 91142  /share/data/external-datasets/compoundcenter/s...
#
#                                                       C3  \
# 0      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 1      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 2      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 3      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 4      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# ...                                                  ...
# 91138  /share/data/external-datasets/compoundcenter/s...
# 91139  /share/data/external-datasets/compoundcenter/s...
# 91140  /share/data/external-datasets/compoundcenter/s...
# 91141  /share/data/external-datasets/compoundcenter/s...
# 91142  /share/data/external-datasets/compoundcenter/s...
#
#                                                       C4  \
# 0      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 1      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 2      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 3      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 4      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# ...                                                  ...
# 91138  /share/data/external-datasets/compoundcenter/s...
# 91139  /share/data/external-datasets/compoundcenter/s...
# 91140  /share/data/external-datasets/compoundcenter/s...
# 91141  /share/data/external-datasets/compoundcenter/s...
# 91142  /share/data/external-datasets/compoundcenter/s...
#
#                                                       C5  \
# 0      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 1      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 2      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 3      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# 4      /share/mikro/IMX/MDC_pharmbio/specs935-v1/spec...
# ...                                                  ...
# 91138  /share/data/external-datasets/compoundcenter/s...
# 91139  /share/data/external-datasets/compoundcenter/s...
# 91140  /share/data/external-datasets/compoundcenter/s...
# 91141  /share/data/external-datasets/compoundcenter/s...
# 91142  /share/data/external-datasets/compoundcenter/s...
#
#                                             moa
# 0      cytochrome P450 inhibitor|SIRT activator
# 1      cytochrome P450 inhibitor|SIRT activator
# 2      cytochrome P450 inhibitor|SIRT activator
# 3      cytochrome P450 inhibitor|SIRT activator
# 4      cytochrome P450 inhibitor|SIRT activator
# ...                                         ...
# 91138             serotonin receptor antagonist
# 91139             serotonin receptor antagonist
# 91140             serotonin receptor antagonist
# 91141             serotonin receptor antagonist
# 91142             serotonin receptor antagonist
#
# [91143 rows x 10 columns]
