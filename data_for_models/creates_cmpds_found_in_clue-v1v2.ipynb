# %% [markdown]
# # Creates Compound CSV with Only Compounds From Specs V1 and V2 that also Can be Found in Clue

# %%
import pandas as pd
import numpy as np

# %%
# importing relevant data frames
clue_sig_in_SPECS = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/04_Tomics_Models/init_data_expl/clue_sig_in_SPECS1&2.csv', delimiter = ",")
cmpds_v1v2 = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/data_for_models/compounds_v1v2.csv')

# %%
clue_sig_in_SPECS.head(3)
# Out:
#    Unnamed: 0    pert_id Compound ID   Batch nr                         moa  \
# 0           0  A39052811   CBK290537  BJ1898259  serotonin receptor agonist
# 1           1  A39052811   CBK290537  BJ1898259  serotonin receptor agonist
# 2           2  A39052811   CBK290537  BJ1898259  serotonin receptor agonist
#
#   bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  ...  \
# 0        b18          10.0       10.0             uM      10 uM  ...
# 1        b18          10.0       10.0             uM      10 uM  ...
# 2        b18          10.0       10.0             uM      10 uM  ...
#
#   cell_iname  det_wells                                         det_plates  \
# 0       WI38        D04  LUNG001_WI38_24H_X1_B18|LUNG001_WI38_24H_X2_B1...
# 1       NL20        D04    LUNG001_NL20_24H_X1_B18|LUNG001_NL20_24H_X3_B18
# 2       A549        D04    LUNG001_A549_24H_X1_B18|LUNG001_A549_24H_X2_B18
#
# ...

# %%
clue_sig_in_SPECS
# Out:
#    Unnamed: 0    pert_id Compound ID   Batch nr                         moa  \
# 0           0  A39052811   CBK290537  BJ1898259  serotonin receptor agonist
#
#   bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  ...  \
# 0        b18          10.0       10.0             uM      10 uM  ...
#
#   cell_iname  det_wells                                         det_plates  \
# 0       WI38        D04  LUNG001_WI38_24H_X1_B18|LUNG001_WI38_24H_X2_B1...
#
#                                           distil_ids build_name  project_code  \
# 0  LUNG001_WI38_24H_X1_B18:D04|LUNG001_WI38_24H_X...        NaN          LUNG
#
#    cmap_name  is_exemplar_sig  is_ncs_sig  is_null_sig
# 0  mosapride              0.0         0.0          0.0
#
# [1 rows x 41 columns]

# %%
cmpds_v1v2
# Out:
#       Unnamed: 0 Compound_ID   Batch_nr CUSTOMER_ID            MOLFORMULA  \
# 0              0   CBK290537  BJ1898259   A39052811  C21H25ClFN3O3.C6H8O7
# 1              1   CBK308456  BJ1896690   A54275602          C14H10ClN3S2
# 2              2   CBK200938  BJ1897571   A84465106            C20H24N2O6
# 3              3   CBK290948  BJ1899032   K05977823           C20H23N3O2S
# 4              4   CBK200855  BJ1895358   K09255212             C9H5ClINO
# ...          ...         ...        ...         ...                   ...
# 1929         994   CBK309598  BJ1899098   A62841832             C10H15BrO
# 1930         995   CBK293562  BJ1894045   A62890442   2C5H11NO2.C10H8O6S2
# 1931         996   CBK290667  BJ1898465   A63236097              C20H30O5
# 1932         997   CBK200599  BJ1895308   A63310107              C8H17NO5
# 1933         998   CBK308191  BJ1896361   A63344375      4C26H24FN3O3.H2O
#
#       MOLWEIGHT               NAME                         VENDOR  \
# ...

# %%
moa_column = clue_sig_in_SPECS["Compound ID"].drop_duplicates() 
clue_in_compoundsv1v2 = cmpds_v1v2[cmpds_v1v2["Compound_ID"].isin(moa_column.tolist())].reset_index(drop= True)

# %%
clue_in_compoundsv1v2
# Out:
#      Unnamed: 0 Compound_ID   Batch_nr CUSTOMER_ID            MOLFORMULA  \
# 0             0   CBK290537  BJ1898259   A39052811  C21H25ClFN3O3.C6H8O7
# 1             2   CBK200938  BJ1897571   A84465106            C20H24N2O6
# 2             3   CBK290948  BJ1899032   K05977823           C20H23N3O2S
# 3             4   CBK200855  BJ1895358   K09255212             C9H5ClINO
# 4             6   CBK015802  BJ1895142   K17075857             C9H5Cl2NO
# ..          ...         ...        ...         ...                   ...
# 977         986   CBK041372  BJ1894782   A62035778         C17H21NO4.HBr
# 978         987   CBK041041  BJ1894209   A62057054              C20H25NO
# 979         989   CBK308856  BJ1897289   A62182663          C17H13Cl2NO4
# 980         995   CBK293562  BJ1894045   A62890442   2C5H11NO2.C10H8O6S2
# 981         996   CBK290667  BJ1898465   A63236097              C20H30O5
#
#      MOLWEIGHT                      NAME                         VENDOR  \
# ...

# %%
clue_in_compoundsv1v2.to_csv('/home/jovyan/Tomics-CP-Chem-MoA/data_for_models/clue_cmpds_in_cmpdsv1v2.csv')

# %%
pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/data_for_models/paths_to_channels_creation/dmso_stats_v1v2.csv')
# Out:
#   Unnamed: 0             P015076          P015076.1           P015076.2  \
# 0        NaN                  C1                 C2                  C3
# 1          m  298.56553513638613  1182.599314422301  1740.3659357495999
# 2        std  280.17719870419074  1628.216043824049   846.2971853421564
#
#             P015076.3          P015076.4             P015077  \
# 0                  C4                 C5                  C1
# 1  1364.0816585652478  682.3957518471755  333.64529227135034
# 2  1029.1825133612128  704.7482234564715  339.08582350494197
#
#             P015077.1          P015077.2           P015077.3  \
# 0                  C2                 C3                  C4
# 1  1350.6730676892814  2163.296099828229   1633.245623894769
# 2  1606.9584977581317  1011.646483085695  1160.5192705314935
#
#            P015077.4
# 0                 C5
# 1  846.2881181705169
# 2  813.9777711274285
